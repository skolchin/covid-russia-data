# %%
# Визуализация данных

import pandas as pd
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = (12, 8)
df = pd.read_excel('covid_russia.xlsx', parse_dates=['period'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1672 entries, 0 to 1671
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   subject                 1672 non-null   object
#  1   total_deaths            1672 non-null   int64
#  2   confirmed_covid_deaths  1672 non-null   int64
#  3   possible_covid_deaths   1660 non-null   float64
#  4   period                  1672 non-null   datetime64[ns]
#  5   reg_code                1672 non-null   int64
#  6   fo_name                 1672 non-null   object
#  7   fo_short_name           1672 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(3), object(3)
# memory usage: 104.6+ KB

# %%
_ = df[ df.reg_code == 77 ][['period', 'confirmed_covid_deaths']].set_index('period').plot()
